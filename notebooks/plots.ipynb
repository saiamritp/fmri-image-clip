# %%
from nilearn import plotting
from nilearn import image

# %%
img_path = '/home2/prateekj/tether-assgn/data-org/CSI1_GLMbetas-TYPED-FITHRF-GLMDENOISE-RR_ses-01.nii.gz'
print(image.load_img(img_path).shape)
first_rsn = image.index_img(img_path, 0)
print(first_rsn.shape)
plotting.plot_stat_map(first_rsn, threshold=1)
# Out:
# (71, 89, 72, 370)
# (71, 89, 72)
# /home2/prateekj/miniconda3/envs/bold5000_env/lib/python3.9/site-packages/nilearn/plotting/img_plotting.py:1416: UserWarning: Non-finite values detected. These values will be replaced with zeros.
#   safe_get_data(stat_map_img, ensure_finite=True),

# %%
plotting.plot_glass_brain(first_rsn, threshold=1)

# %%
plotting.plot_glass_brain(
    first_rsn,
    title="plot_glass_brain",
    black_bg=True,
    display_mode="xz",
    threshold=3,
)

# %%
plotting.plot_glass_brain(
    first_rsn,
    title='plot_glass_brain with display_mode="lyrz"',
    display_mode="lyrz",
    threshold=3,
)

plotting.show()
